# %% [markdown]
# #### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Data
#
# Source you can find <a href="https://www.kaggle.com/datasets/brendan45774/test-file">here</a>.

# %%
data = pd.read_csv("data/titanic.csv")
data.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10, 5))
plt.hist(data.Age, bins=32, color='red')
plt.xticks(np.arange(0, 81, 5))
plt.title('Age')
plt.show()

# %% [markdown]
# # Density plot

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(data, x='Age', bw_adjust=1, color='red', fill=True)
plt.title("Age")
plt.show()

# %% [markdown]
# # Stacked histogram

# %%
notSurvived = data[data['Survived'] == 0]['Age']
survived = data[data['Survived'] == 1]['Age']

plt.figure(figsize=(10, 5))
plt.hist([notSurvived, survived], bins = 16, stacked = True, color=['#714da1', '#b57dff'])
plt.xticks(np.arange(0, 76, 5))
plt.title("Survivability by age")
plt.xlabel("Age")
plt.legend(["Not survived", "Survived"])
plt.show()

# %% [markdown]
# # Stacked density plot

# %% [markdown]
# <a href="https://matplotlib.org/stable/users/explain/colors/colormaps.html">Matplotlib colormaps</a>

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(data, x='Age', hue='Survived', multiple='stack', fill=True, palette='Blues')
plt.title("Survivability by age")
plt.legend(["No", "Yes"])
plt.show()

# %% [markdown]
# # Overlapping histograms

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data, x='Age', hue='Pclass', palette='spring', bins=19)
plt.xticks(np.arange(0, 77, 4))
plt.title("Service classes by age")
plt.show()

# %% [markdown]
# # Overlapping density plots

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(data, x='Age', hue='Pclass', fill=True, palette='spring', cut=0)
plt.title("Service classes by age")
plt.show()

# %% [markdown]
# # Ridge chart

# %% [markdown]
# # Population pyramid

# %% [markdown]
# # Q-Q plots

# %% [markdown]
# # Graphs with high skewness and logarithmic scales

# %% [markdown]
# # Box plots

# %% [markdown]
# # Violin plots

# %% [markdown]
# # Point cloud

# %% [markdown]
# # Strip plot
